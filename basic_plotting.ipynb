# %%
# %matplotlib notebook , but I'm working in visual studio hahaha
import matplotlib as mpl
import pandas as pd
mpl.get_backend()
# Out:
# 'module://matplotlib_inline.backend_inline'

# %%
# import the scripting layer, here it's pyplot
import matplotlib.pyplot as plt
# plt.plot? <-- Use this to get the help text from the method.

# %% [markdown]
# Let's try with a simple example

# %%
plt.plot(3,2)
# it returns a line2D Object

# %%
# nothing is displayed, becuase it needs to know how is the data
# representated, and that's the third argument.
plt.plot(3, 2, ".")

# %% [markdown]
# ---
#
# Here we are going to check another way to plot using a different backend

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({
    "normal" : normal_sample, "random": random_sample,
    "gamma": gamma_sample
})
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean       0.005838      0.497877      1.985929
# std        1.005653      0.287020      1.378958
# min       -3.965617      0.000145      0.008955
# 25%       -0.670594      0.249840      0.959594
# 50%        0.009863      0.496432      1.682431
# 75%        0.679176      0.743506      2.692569
# max        3.539171      0.999880     10.492270

# %%
plt.figure()
_ = plt.boxplot(df["normal"])

# %%
plt.figure()
_ = plt.boxplot([df["normal"], df["random"], df["gamma"]])

# %%
plt.figure()
_ = plt.hist(df["gamma"], bins=100)
